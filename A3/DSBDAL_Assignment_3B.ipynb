# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvmahajan/TE/blob/DSBDAL/DSBDAL_Assignment_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### DSBDAL Assignment 3B
# Name : Sharv Mahajan
#
# Roll No. : 31430

# %% [markdown]
# # Descriptive Statistics - Iris Dataset
#
# Objective
#
# To write a Python program that displays basic statistical details such as:
#
# - Mean
#
# - Standard Deviation
#
# - Percentiles (25%, 50%, 75%)
#
# for the species:
#
# - Iris-setosa
#
# - Iris-versicolor
#
# - Iris-virginica
#
# using the **Iris CSV dataset**.

# %% [markdown]
# ## Import Libraries:

# %%
import pandas as pd

# %% [markdown]
# Explanation:
#
# - `pandas` is used for data manipulation and statistical analysis.

# %% [markdown]
# ## Load the Iris Dataset
#
# [Dataset](https://www.kaggle.com/datasets/himanshunakrani/iris-dataset)

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Mean, Median, Min, Max & Standard Deviation (Species-wise)

# %%
grouped_stats = df.groupby("species").agg(
    mean=("sepal_length", "mean"),
    std=("sepal_length", "std"),
    min=("sepal_length", "min"),
    max=("sepal_length", "max"),
    median=("sepal_length", "median")
)

grouped_stats
# Out:
#              mean       std  min  max  median
# species
# setosa      5.006  0.352490  4.3  5.8     5.0
# versicolor  5.936  0.516171  4.9  7.0     5.9
# virginica   6.588  0.635880  4.9  7.9     6.5

# %% [markdown]
# Explanation:
#
# - The data is grouped by `species`.
#
# - Descriptive statistics are calculated for **sepal length**.

# %% [markdown]
# ## Percentiles, Mean & Standard Deviation for All Features

# %%
percentile_stats = df.groupby("species").describe(percentiles=[0.25, 0.5, 0.75])
percentile_stats
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %% [markdown]
# Explanation:
#
# - `describe()` generates:
#
#   - Count
#
#   - Mean
#
#   - Standard deviation
#
#   - Minimum & maximum
#
#   - 25th, 50th (median), and 75th percentiles
#
# - Statistics are calculated separately for each species and each numeric attribute.
