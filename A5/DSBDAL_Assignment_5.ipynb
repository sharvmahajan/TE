# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvmahajan/TE/blob/DSBDAL/A5/DSBDAL_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DSBDAL Assignment 5
#
# Name: Sharv Mahajan
#
# Roll No. : 31430

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Loading Dataset

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ###Basic Initial Survey

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %% [markdown]
# ##Data Cleaning
# ### Handling Missing Values
#
# - Age → filled using median
#
# - Embarked → filled using mode

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# ## Survival Stats

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Survived", data=df)

plt.title("Survival Count (0 = No, 1 = Yes)")
plt.show()

# %% [markdown]
# ###Box Plot of Age Distribution w.r.t Gender and Survival

# %%
plt.figure(figsize=(10,6))

sns.boxplot(x="Sex", y="Age", hue="Survived", data=df)

plt.title("Box Plot of Age Distribution by Gender and Survival")
plt.xlabel("Gender")
plt.ylabel("Age")
plt.legend(title="Survived (0 = No, 1 = Yes)")
plt.show()

# %% [markdown]
# **Inferences from the Box Plot**
#
# 1. **Female passengers had a higher survival rate**
#
#     The survived (orange) box for females is more prominent, showing that more females survived compared to males.
#
# 2. **Male passengers show higher deaths across all age groups**
#
#     The non-survived (blue) box for males is larger, indicating that many male passengers did not survive.
#
# 3. **Median age is similar for survived and non-survived males**
#
#     For males, the median age line in both survived and non-survived groups lies around the late 20s, meaning survival was not strongly dependent on age for men.
#
# 4. **Surviving females tend to be slightly younger**
#
#     The median age of survived females is slightly lower compared to non-survived females, suggesting younger women had better chances.
#
# 5. **Children had better survival chances**
#
#     Lower age values appear more in the survived category, indicating that children were more likely to survive.
#
# 6. **Older passengers are mostly in the non-survived group**
#
#     Many higher-age outliers are present in the non-survived category, showing that elderly passengers had lower survival probability.
#
# 7. **Age distribution is wider among males**
#
#     Male passengers have more outliers and a wider spread, meaning males of many different age groups were aboard, but survival was still low.

# %% [markdown]
# Overall, the plot suggests that **gender played a major role in survival**, with **females having significantly higher survival chances**. Age also mattered, as **children survived more**, while **older passengers had lower survival rates**.
